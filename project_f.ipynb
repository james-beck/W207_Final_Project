# %%
import pandas as pd
import json
import numpy as np
from sklearn.feature_extraction.text import *
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

with open('train.json') as data_file:    
    data = json.load(data_file)

X = []
y =[]
for item in data:
    X.append(', '.join(item['ingredients']))
    y.append(item['cuisine'])    

X_train, X_dev, y_train, y_dev = train_test_split(X, y, random_state=2)

# %%
print(len(X_train))
print(len(X_dev))
# Out:
# 29830
# 9944

# %%
#simplest version
#f1_score is .775
cv = CountVectorizer()
tf_X_train = cv.fit_transform(X_train)
tf_X_dev = cv.transform(X_dev)

# %%
lr = LogisticRegression()
lr.fit(tf_X_train, y_train)
predictions = lr.predict(tf_X_dev)

# %%
print(classification_report(y_dev, predictions))
print(metrics.f1_score(y_dev, predictions, average='weighted'))
# Out:
#               precision    recall  f1-score   support
#
#    brazilian       0.76      0.55      0.63       121
#      british       0.59      0.33      0.43       206
# cajun_creole       0.78      0.70      0.74       376
#      chinese       0.79      0.85      0.82       670
#     filipino       0.71      0.54      0.61       190
#       french       0.59      0.64      0.61       636
#        greek       0.76      0.70      0.73       258
#       indian       0.85      0.89      0.87       758
#        irish       0.67      0.47      0.55       175
#      italian       0.80      0.90      0.85      1963
#     jamaican       0.81      0.70      0.75       123
#     japanese       0.82      0.69      0.75       342
#       korean       0.84      0.74      0.79       221
#      mexican       0.91      0.92      0.91      1668
#     moroccan       0.81      0.78      0.80       215
#      russian       0.66      0.40      0.50       133
#  southern_us       0.69      0.77      0.73      1056
#      spanish       0.63      0.43      0.51       247
#         thai       0.78      0.77      0.78       391
#   vietnamese       0.68      0.58      0.63       195
#
#  avg / total       0.78      0.78      0.78      9944
#
# 0.775129698146

# %%
#using single words or pairs of words
#note - limiting it to those that appear 10 times (min_df=10) made it worse
#slight improvement - f1_score is .780
cv_bigrams = CountVectorizer(ngram_range=(1,2))
tf_X_train_bigrams = cv_bigrams.fit_transform(X_train)
tf_X_dev_bigrams = cv_bigrams.transform(X_dev)

# %%
lr_bigrams = LogisticRegression()
lr_bigrams.fit(tf_X_train_bigrams, y_train)
predictions = lr.predict(tf_X_dev_bigrams)

# %%
print(classification_report(y_dev, predictions))
print(metrics.f1_score(y_dev, predictions, average='weighted'))
# Out:
#               precision    recall  f1-score   support
#
#    brazilian       0.77      0.55      0.64       121
#      british       0.53      0.34      0.41       206
# cajun_creole       0.80      0.72      0.76       376
#      chinese       0.82      0.85      0.83       670
#     filipino       0.69      0.59      0.63       190
#       french       0.58      0.64      0.61       636
#        greek       0.76      0.67      0.72       258
#       indian       0.86      0.89      0.87       758
#        irish       0.68      0.46      0.55       175
#      italian       0.80      0.90      0.85      1963
#     jamaican       0.84      0.67      0.74       123
#     japanese       0.82      0.71      0.76       342
#       korean       0.86      0.75      0.80       221
#      mexican       0.91      0.92      0.92      1668
#     moroccan       0.84      0.77      0.80       215
#      russian       0.75      0.41      0.53       133
#  southern_us       0.70      0.78      0.74      1056
#      spanish       0.65      0.46      0.54       247
#         thai       0.78      0.80      0.79       391
#   vietnamese       0.70      0.59      0.64       195
#
#  avg / total       0.78      0.79      0.78      9944
#
# 0.780411898855

# %%
#print out the heaviest weights -both positive and negative - for each cuisineb


largestWeightedWords = []
largestWeightedIndeces = []
cv_bigram_featurenames = cv_bigrams.get_feature_names()
cats = ['brazilian', 'british', 'cajun_creole', 'chinese', 'filipino', 'french', 'greek', 'indian', 'irish', 'italian', 'jamaican','japanese', 'korean', 'mexican', 'moroccan', 'russian', 'southern_us', 'spanish', 'thai', 'vietnamese']


for cat in range(20):
    print(cats[cat])
    weightIndeces = np.argsort(abs(lr_bigrams.coef_[cat]))[-5:]
    for index in weightIndeces:
        weight = lr_bigrams.coef_[cat][index]
        
        print(cv_bigram_featurenames[index] + " " + str(weight))
    print('\n')
# Out:
# brazilian
# manioc 1.81684210974
# manioc flour 1.81684210974
# black beans 1.8963307854
# tapioca flour 1.94343426701
# cachaca 4.42654489565
#
#
# british
# stilton cheese 1.58576911257
# jam 1.60918448539
# mincemeat 1.70117801631
# marmite 2.14242286153
# stilton 3.28159490246
#
#
# cajun_creole
# oil powdered 1.39534041956
# powder dried 1.50187637936
# cajun seasoning 1.67942575972
# creole 2.32921833546
# cajun 2.3873676481
#
#
# chinese
# szechwan peppercorns 1.58492318786
# kimchi -1.62362458022
# mandarin 1.80026540523
# sake -1.89346466114
# mirin -2.62748695135
#
#
# filipino
# tilapia 1.38693410006
# mirin -1.42974680294
# basil -1.49834913221
# calamansi 1.94418668915
# lumpia 1.97017120327
#
#
# french
# snails 1.60195331392
# grits -1.75811624417
# duck 1.76781095857
# pasta -1.77045743012
# cognac 1.99113545665
#
#
# greek
# phyllo 2.25904621531
# tahini 2.27620076599
# feta cheese 2.56303692104
# feta 2.63273494929
# greek 2.91312357351
#
#
# indian
# curds 1.95553708379
# tandoori 2.20226763204
# masala 2.23408928644
# curry 2.41600137731
# yoghurt 2.5569324714
#
#
# irish
# brisket 1.62399168802
# corned 1.64929451772
# corned beef 1.64929451772
# potatoes 2.08766721311
# irish 3.42819439415
#
#
# italian
# gnocchi 2.38416028031
# grits -2.53939486774
# mascarpone 2.586261533
# spaghetti 2.91986886476
# polenta 3.37725611771
#
#
# jamaican
# nutmeg 1.7417191799
# rum 1.99001680133
# allspice 2.84641393647
# thyme 2.92833062476
# jerk 3.95608932431
#
#
# japanese
# nori 2.29715638204
# dashi 2.52074750699
# sake 3.25246328211
# mirin 3.28183526961
# miso 3.53743665137
#
#
# korean
# eggs carrots 1.61012295175
# gochujang base 1.87625770878
# gochujang 1.87625770878
# pinenuts 2.12262919487
# kimchi 3.57471117032
#
#
# mexican
# salsa 2.42769819422
# taco 2.59635483945
# mexican 2.65869795187
# tequila 3.25734346443
# tortillas 3.42142600371
#
#
# moroccan
# lemon kosher 1.98469828928
# green tea 2.05966586757
# cinnamon 2.08661838155
# harissa 2.32639844989
# couscous 2.89469631431
#
#
# russian
# sour 1.21574355848
# cabbage 1.29575819935
# sauerkraut 1.6162959677
# dill 1.76339369286
# beets 2.79842218635
#
#
# southern_us
# biscuits 2.12138749618
# peaches 2.51371674222
# green tomatoes 3.05342863133
# sweet potatoes 3.34637272559
# grits 4.57476681211
#
#
# spanish
# sherry 1.55200008081
# saffron 1.59125878845
# manchego 1.72867682475
# manchego cheese 1.73389815715
# chorizo 2.33126946538
#
#
# thai
# sticky rice 1.52925213178
# curry paste 1.55096240727
# coconut milk 1.5708241851
# peanut 1.58470080106
# thai 1.82211649119
#
#
# vietnamese
# maggi 1.49812864414
# cheese -1.64093275042
# vietnamese 1.64719558715
# tapioca 1.78900773411
# fish sauce 1.90328377208

# %%
#should format this into a pandas df
cm = confusion_matrix(y_dev, predictions)
cmdf = pd.DataFrame(cm, index = cats, columns = cats)
print(cmdf)
# Out:
#               brazilian  british  cajun_creole  chinese  filipino  french  \
# brazilian            66        0             3        0         2       3
# british               1       70             2        0         3      40
# cajun_creole          1        2           271        2         0      11
# chinese               0        1             4      569         9       2
# filipino              3        2             1       17       112       4
# french                0        6             5        1         5     408
# greek                 0        0             0        1         0       6
# indian                1        2             0        3         1       6
# irish                 0       16             0        1         0      17
# italian               0        7             4        3         3      78
# jamaican              2        4             1        2         2       0
# japanese              2        2             0       24         2      10
# korean                0        0             0       26         4       1
# mexican               4        1             6        3         5      17
# moroccan              0        0             3        1         0       3
# russian               0        6             2        0         1      18
# southern_us           3       11            34        7         4      48
# spanish               1        2             1        0         1      26
# thai                  2        0             1       22         5       0
# vietnamese            0        0             0       16         4       2
#
#               greek  indian  irish  italian  jamaican  japanese  korean  \
# brazilian         0       4      0        7         5         0       0
# british           0       6     10       14         0         1       0
# cajun_creole      2       1      0       20         1         0       2
# chinese           0       6      0        4         0        18      11
# filipino          0       2      1        8         0         2       0
# french            5       4      7      121         0         1       0
# greek           174       6      0       53         0         0       0
# indian            9     672      1       15         0         7       0
# irish             1       2     80       16         0         0       0
# italian          18       5      4     1772         0         0       1
# jamaican          1       8      0        4        82         2       1
# japanese          1      26      0        7         0       243       7
# korean            0       0      0        4         0        12     166
# mexican           3       8      0       33         1         1       1
# moroccan          6      15      1        9         1         1       0
# russian           3       1      3       24         0         1       0
# southern_us       1       2      9       53         7         4       1
# spanish           3       2      1       54         0         0       0
# thai              0       9      0        2         1         2       1
# vietnamese        1       2      0        5         0         2       1
#
#               mexican  moroccan  russian  southern_us  spanish  thai  \
# brazilian          13         0        1            9        5     3
# british             2         1        3           51        2     0
# cajun_creole        9         0        0           53        1     0
# chinese             7         1        1           11        0    13
# filipino            8         0        1           16        1     7
# french              6         3        5           48       11     0
# greek               0         5        1            5        6     1
# indian             15        11        0            3        1    11
# irish               0         1        2           35        3     1
# italian            16         4        0           40        8     0
# jamaican            3         0        0            9        0     1
# japanese            5         0        0            6        0     5
# korean              1         0        0            3        0     1
# mexican          1541         0        0           32       11     1
# moroccan            1       165        0            5        3     0
# russian             6         1       54           11        1     1
# southern_us        34         0        3          825        8     1
# spanish            20         4        1           17      113     0
# thai                6         1        0            4        0   312
# vietnamese          6         0        0            1        0    40
#
#               vietnamese
# brazilian              0
# british                0
# cajun_creole           0
# chinese               13
# filipino               5
# french                 0
# greek                  0
# indian                 0
# irish                  0
# italian                0
# jamaican               1
# japanese               2
# korean                 3
# mexican                0
# moroccan               1
# russian                0
# southern_us            1
# spanish                1
# thai                  23
# vietnamese           115
# (20L, 20L)

# %%
#find biggest mistakes
pred_probs = lr.predict_log_proba(tf_X_dev_bigrams)

rs = []
for i in range(pred_probs.shape[0]):
    #print(i)
    probs = pred_probs[i]
    maxprob = np.exp(np.max(probs))
    correctprob = np.exp(probs[cats.index(y_dev[i])])
    rs.append(maxprob/correctprob)
len(rs)
# Out:
# 9944

# %%
biggestMistakeIndeces = np.argsort(rs)[-20:]
for index in biggestMistakeIndeces:
    print(index)
    print('Real category: ' + y_dev[index])
    print('Probabilities:', np.exp(pred_probs[index]))
    print('Predicted category: ' + cats[np.where(pred_probs[index]==np.max(pred_probs[index]))[0][0]])
    print(rs[index])
    print('\n\n' + X_dev[index] + '\n\n')
# Out:
# 2167
# Real category: russian
# ('Probabilities:', array([  2.66931432e-05,   7.22968802e-01,   6.48334926e-05,
#          8.45222784e-04,   3.74739540e-07,   2.78857247e-02,
#          7.74505515e-06,   1.13152864e-01,   2.36254112e-03,
#          4.69334972e-02,   4.00059541e-03,   7.02108197e-04,
#          8.29881893e-05,   1.48489817e-03,   8.39546786e-05,
#          3.41201498e-04,   7.90020480e-02,   8.38741082e-06,
#          2.45087796e-05,   2.10115252e-05]))
# Predicted category: british
# 2118.89105649
#
#
# warm water, light molasses, large eggs, whipping cream, ground cinnamon, baking soda, semisweet chocolate, light corn syrup, all-purpose flour, ground ginger, golden brown sugar, unsalted butter, baking powder, salt, ground cloves, crystallized ginger, peeled fresh ginger, vanilla extract
#
#
# 6900
# Real category: vietnamese
# ('Probabilities:', array([  2.85525030e-05,   4.89874605e-06,   2.92045079e-05,
#          9.83721429e-01,   6.29499266e-04,   7.77219600e-05,
#          1.18148458e-05,   5.76288756e-04,   2.76380172e-06,
#          8.34634359e-04,   1.75234265e-04,   4.64085187e-03,
#          1.00391270e-03,   5.00434036e-05,   1.47190545e-05,
#          3.83256539e-05,   1.81087177e-04,   5.19723716e-05,
#          7.51953472e-03,   4.07510936e-04]))
# Predicted category: chinese
# 2413.9755345
#
#
# soy sauce, sesame oil, corn starch, chicken broth, broccoli florets, crushed red pepper flakes, ginger root, minced garlic, red wine vinegar, Foster Farms boneless skinless chicken breasts, sugar, green onions, oil
#
#
# 4288
# Real category: mexican
# ('Probabilities:', array([  6.29099690e-05,   2.23928706e-04,   7.02262025e-04,
#          1.02183541e-05,   6.59951350e-06,   5.40072937e-02,
#          6.20430820e-03,   1.41915721e-04,   1.59294808e-03,
#          9.20787641e-01,   1.12607872e-05,   1.39834072e-03,
#          1.64984343e-04,   3.53860938e-04,   4.68718585e-03,
#          4.91459107e-04,   3.96859973e-03,   4.42051322e-03,
#          6.60508486e-04,   1.03261890e-04]))
# Predicted category: italian
# 2602.11721973
#
#
# ground black pepper, grated lemon zest, fresh basil, extra-virgin olive oil, fresh lemon juice, large garlic cloves, anchovy fillets, capers, cornichons, flat leaf parsley
#
#
# 9308
# Real category: chinese
# ('Probabilities:', array([  7.16828250e-04,   9.93698205e-06,   1.48067160e-03,
#          3.54972313e-04,   3.54833228e-03,   2.76924101e-04,
#          3.84821568e-04,   3.94086432e-03,   3.26125557e-04,
#          1.38125658e-05,   1.68718858e-04,   2.07871198e-04,
#          2.63949881e-05,   3.80471525e-02,   3.39669545e-04,
#          2.23963386e-04,   9.38459963e-01,   7.63689860e-03,
#          1.83311018e-03,   2.00296786e-03]))
# Predicted category: southern_us
# 2643.75537947
#
#
# water, jalapeno chilies, cucumber, corn kernels, green tomatoes, celery seed, sugar, chopped green bell pepper, salt, red bell pepper, cider vinegar, finely chopped onion, carrots, ground turmeric
#
#
# 8174
# Real category: greek
# ('Probabilities:', array([  1.17764854e-03,   3.29337188e-04,   9.62532192e-04,
#          5.29711647e-03,   2.22849481e-03,   1.31120124e-02,
#          2.92624341e-04,   2.32174167e-03,   1.05950799e-02,
#          9.46229577e-01,   4.25272344e-03,   2.26137044e-03,
#          7.67544728e-04,   3.24295598e-03,   9.39695217e-04,
#          2.45784622e-04,   3.04596430e-03,   1.31687081e-03,
#          3.84731427e-04,   9.96194863e-04]))
# Predicted category: italian
# 3233.59831592
#
#
# yellow bell pepper, baby spinach leaves, pasta sauce, goat cheese, prepared pizza crust
#
#
# 1195
# Real category: filipino
# ('Probabilities:', array([  2.36720973e-04,   3.96634722e-04,   5.57119688e-02,
#          3.38702141e-04,   2.30154689e-04,   2.00914506e-03,
#          4.07184548e-03,   3.52318982e-03,   3.98058562e-04,
#          8.93772156e-03,   5.04933419e-04,   1.87163906e-03,
#          4.96641990e-04,   8.92070455e-01,   1.60060250e-03,
#          6.32153777e-04,   1.68573398e-02,   8.88477951e-03,
#          9.04020791e-04,   3.23291896e-04]))
# Predicted category: mexican
# 3875.96037614
#
#
# onion powder, ground cumin, ground black pepper, salt, garlic powder, paprika, chili powder, dried oregano
#
#
# 7600
# Real category: spanish
# ('Probabilities:', array([  4.75776347e-03,   3.51944918e-02,   9.95630568e-05,
#          9.70043179e-05,   1.52010137e-04,   8.14539669e-01,
#          1.35110039e-01,   1.15723883e-04,   1.64257278e-03,
#          7.84540530e-04,   2.04490753e-05,   3.81046253e-05,
#          2.40195865e-04,   4.83459989e-04,   4.75445871e-03,
#          5.05162048e-04,   1.16524891e-03,   2.04411019e-04,
#          8.39179324e-06,   8.67395924e-05]))
# Predicted category: french
# 3984.81292847
#
#
# bread crumb fresh, leeks, kalamata, carrots, fresh rosemary, dijon mustard, shallots, garlic cloves, water, bay leaves, dry red wine, onions, tomatoes, olive oil, lamb neck, rack of lamb
#
#
# 4033
# Real category: filipino
# ('Probabilities:', array([  5.30498306e-07,   2.19295438e-07,   1.21610413e-06,
#          9.49851692e-01,   2.29802646e-04,   5.69926537e-07,
#          4.95083015e-05,   5.50532327e-07,   4.41609601e-07,
#          9.84769218e-06,   1.26963675e-05,   2.34265898e-02,
#          7.21664466e-04,   5.38956009e-07,   1.33008272e-05,
#          1.40154118e-06,   3.33128924e-06,   1.09855179e-06,
#          9.40201945e-03,   1.62729806e-02]))
# Predicted category: chinese
# 4133.33662306
#
#
# ground ginger, shiitake, water chestnuts, vegetable oil, sauce, toasted sesame seeds, honey, hoisin sauce, rice noodles, rice vinegar, red bell pepper, pepper, zucchini, sesame oil, pea pods, scallions, soy sauce, beef, broccoli florets, garlic, orange juice, bamboo shoots
#
#
# 8389
# Real category: spanish
# ('Probabilities:', array([  8.70885600e-04,   5.22988379e-02,   7.33055720e-04,
#          2.57008691e-03,   5.32437381e-04,   4.02498642e-03,
#          1.69945932e-03,   5.15175068e-04,   2.92582435e-02,
#          9.65374861e-03,   2.09011218e-03,   1.58738534e-03,
#          1.10499477e-02,   8.82581227e-03,   7.90465027e-04,
#          6.01545766e-03,   8.63382075e-01,   1.72269077e-04,
#          1.10075969e-03,   2.82879941e-03]))
# Predicted category: southern_us
# 5011.8227232
#
#
# white vinegar, brown sugar, granulated sugar, ground cinnamon, ground cloves, all-purpose flour, ground ginger, shortening, buttermilk, eggs, baking soda
#
#
# 5159
# Real category: brazilian
# ('Probabilities:', array([  1.49041900e-04,   1.15229193e-01,   2.40584504e-03,
#          2.08634730e-05,   2.86089779e-06,   8.63167587e-01,
#          1.06880590e-03,   1.17876097e-04,   8.45917070e-04,
#          5.29472028e-03,   6.61562828e-06,   1.98837605e-04,
#          2.39240477e-04,   3.60799835e-03,   1.17437860e-04,
#          2.77173024e-03,   4.17530951e-03,   5.13232919e-04,
#          4.51886175e-05,   2.16982002e-05]))
# Predicted category: french
# 5791.44245426
#
#
# sugar, unsalted butter, whipping cream, fresh lemon juice, white chocolate, semisweet chocolate, strawberries, large egg yolks, half & half, walnuts, whole almonds, bananas, light corn syrup, dark brown sugar
#
#
# 828
# Real category: southern_us
# ('Probabilities:', array([  3.66325183e-04,   3.85007790e-03,   7.07708236e-01,
#          6.21370581e-02,   2.45663712e-02,   2.46516713e-04,
#          3.35159686e-04,   8.63547036e-05,   3.26829660e-03,
#          1.27502121e-03,   3.43876815e-03,   1.13307760e-01,
#          2.11494774e-02,   6.22569013e-04,   6.52436483e-04,
#          1.73806838e-03,   1.18712338e-04,   4.35785340e-04,
#          4.29096376e-03,   5.04060422e-02]))
# Predicted category: cajun_creole
# 5961.53901729
#
#
# soy sauce, cajun seasoning, beef stock, spaghetti, hard-boiled egg, cooked meat, green onions
#
#
# 6150
# Real category: irish
# ('Probabilities:', array([  8.46060474e-03,   1.10581298e-03,   4.79899008e-03,
#          5.89230024e-03,   2.82090550e-03,   1.30631191e-01,
#          1.78164698e-02,   8.47347597e-03,   5.87041230e-05,
#          5.60706459e-01,   6.38470081e-04,   3.05337049e-03,
#          5.92818440e-03,   5.93873454e-02,   1.90456703e-03,
#          2.49662053e-03,   3.49713131e-02,   1.43770923e-01,
#          4.10540464e-03,   2.97888742e-03]))
# Predicted category: italian
# 9551.39827501
#
#
# olive oil, long-grain rice, water, zucchini, sliced mushrooms, fresh basil, beef, garlic cloves, yellow squash, chopped onion, plum tomatoes
#
#
# 3024
# Real category: chinese
# ('Probabilities:', array([  8.10787409e-04,   4.94488483e-05,   2.41195061e-04,
#          6.68314684e-05,   6.88834799e-06,   1.80377296e-03,
#          4.08690973e-04,   2.13857014e-05,   1.99062030e-05,
#          9.90832524e-01,   7.74314418e-05,   9.61431702e-04,
#          1.50642049e-05,   1.84909707e-04,   1.72137627e-04,
#          1.87790002e-03,   1.23775301e-03,   5.16441027e-05,
#          1.15803483e-03,   2.26225737e-06]))
# Predicted category: italian
# 14825.8380039
#
#
# ground chicken, cracker crumbs, fresh basil, grated parmesan cheese, ricotta cheese, eggs, minced onion, parsley, ketchup, whole cloves, shredded mozzarella cheese
#
#
# 9643
# Real category: filipino
# ('Probabilities:', array([  2.32103598e-02,   1.06348982e-02,   1.19339563e-03,
#          1.02039239e-04,   2.45370222e-05,   3.67324596e-04,
#          4.71944045e-03,   1.68641869e-03,   6.36422384e-05,
#          3.77485020e-03,   6.10161884e-05,   1.13316161e-03,
#          8.11481305e-04,   5.85406293e-01,   5.45920044e-02,
#          1.64065641e-03,   2.89373095e-04,   3.09452075e-01,
#          2.63428108e-05,   8.10690500e-04]))
# Predicted category: mexican
# 23858.0821801
#
#
# vegetable oil, minced beef, ground cumin, beef, extra-virgin olive oil, smoked paprika, boiled eggs, Italian parsley leaves, garlic cloves, chili powder, yellow onion, oregano leaves
#
#
# 7088
# Real category: filipino
# ('Probabilities:', array([  1.74102381e-03,   3.98856145e-04,   2.51173098e-05,
#          2.60672544e-03,   3.22844528e-05,   1.27909255e-04,
#          1.93004146e-05,   4.16270890e-05,   1.41561536e-05,
#          2.92872768e-05,   4.33490732e-04,   5.00257753e-05,
#          1.69290211e-05,   9.61460660e-01,   2.28684591e-05,
#          2.37648125e-05,   3.01932097e-02,   5.16213983e-04,
#          1.77159795e-03,   4.74952001e-04]))
# Predicted category: mexican
# 29780.9185712
#
#
# lime juice, black bean and corn salsa, eggs, jalapeno chilies, frozen corn, pie pastry, chicken strips, fresh cilantro, cheese
#
#
# 7718
# Real category: spanish
# ('Probabilities:', array([  8.31824431e-04,   5.86576689e-02,   2.35301241e-03,
#          4.96654736e-03,   2.74257950e-05,   2.59354779e-02,
#          1.02610511e-02,   4.41623781e-04,   4.64435098e-02,
#          6.46510704e-02,   4.28652719e-04,   2.19682836e-04,
#          1.54335238e-04,   4.14628421e-04,   1.71242117e-02,
#          7.63842885e-01,   2.69840017e-03,   2.55790806e-05,
#          1.19508245e-04,   4.02905083e-04]))
# Predicted category: russian
# 29862.014807
#
#
# warm water, honey, port, walnuts, ground cinnamon, molasses, unsalted butter, all-purpose flour, sugar, active dry yeast, large eggs, candied fruit, ground ginger, ground cloves, baking soda, salt, dried cranberries
#
#
# 7440
# Real category: irish
# ('Probabilities:', array([  3.22847978e-05,   1.21377829e-05,   3.67099561e-04,
#          3.64878082e-05,   3.78357901e-05,   9.09629277e-06,
#          9.31976247e-05,   1.94770145e-05,   9.27080460e-06,
#          9.98662710e-01,   1.19174872e-05,   1.34267634e-05,
#          8.05287105e-05,   5.71738366e-05,   3.77152683e-05,
#          2.09695859e-05,   3.48503443e-04,   6.21977885e-07,
#          1.42892311e-04,   6.65275426e-06]))
# Predicted category: italian
# 107721.255455
#
#
# mozzarella cheese, sweet italian sausage, ground lamb, garlic, italian seasoning, parmigiano reggiano cheese, provolone cheese, tomato sauce, crushed red pepper, rigatoni
#
#
# 7733
# Real category: filipino
# ('Probabilities:', array([  4.85759318e-04,   2.00265681e-05,   3.71558335e-03,
#          8.53745837e-05,   7.28859815e-06,   2.44762781e-03,
#          2.36326460e-03,   8.31332098e-04,   1.23655034e-04,
#          2.31276975e-03,   1.14242124e-01,   1.54481200e-04,
#          6.72741502e-06,   8.38671883e-01,   3.52884411e-03,
#          1.87428558e-05,   3.22288350e-04,   2.37237629e-02,
#          6.62650577e-03,   3.11958114e-04]))
# Predicted category: mexican
# 115066.280991
#
#
# lime juice, green onions, boneless skinless chicken breast halves, olive oil, fresh oregano, fresh cilantro, salt, ground cumin, pepper, fresh thyme, garlic cloves
#
#
# 244
# Real category: russian
# ('Probabilities:', array([  1.02435297e-04,   5.23322505e-04,   1.90323823e-02,
#          2.85691262e-05,   6.92236502e-05,   1.58550855e-04,
#          1.52702404e-03,   3.13300757e-05,   1.18346395e-05,
#          8.96591793e-01,   6.65513119e-05,   1.20324493e-04,
#          7.80354787e-05,   1.14647495e-04,   2.86042318e-04,
#          7.29519200e-06,   6.70494821e-04,   7.99850332e-02,
#          4.70844523e-05,   5.48025809e-04]))
# Predicted category: italian
# 122901.74026
#
#
# fresh rosemary, freshly grated parmesan, red russian kale, onions, minced garlic, Vegeta Seasoning, chickpeas, tomato sauce, ground black pepper, tuscan sausage, chicken stock, olive oil, tomatoes with juice, chopped fresh sage
#
#
# 3095
# Real category: chinese
# ('Probabilities:', array([  1.88168388e-05,   6.01060472e-05,   1.74376379e-02,
#          2.18821040e-07,   1.96810524e-05,   4.92910364e-04,
#          5.73037011e-06,   2.96863087e-08,   5.79875561e-04,
#          5.20588429e-07,   5.43178564e-04,   2.03037273e-05,
#          5.37048704e-06,   8.69284036e-01,   9.70988885e-05,
#          1.26547344e-06,   2.69386764e-03,   1.08721337e-01,
#          6.01271996e-06,   1.20028237e-05]))
# Predicted category: mexican
# 3972579.77349
#
#
# suckling pig, bay leaves, worcestershire sauce, salt, lard, white onion, jalapeno chilies, raisins, red bliss potato, carrots, green apples, tomatoes, ground black pepper, Mexican oregano, fresh orange juice, pimento stuffed olives, fresh lime juice, adobo, fresh thyme, cinnamon, garlic, juice, fresh pineapple
